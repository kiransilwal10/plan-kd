# %% [markdown]
# # Sanity checks\nUse this notebook to quickly inspect parsed samples, adjacency graphs, and teacher outputs.

# %%
import json, pathlib\nfrom PIL import Image\nfrom pprint import pprint\n\ncache = pathlib.Path('../outputs/cache')\nprint('Cache contents', list(cache.glob('*')))\nfor idx_path in cache.glob('*_index.json'):\n    print(idx_path)\n    pprint(json.loads(idx_path.read_text())['samples'][:1])
